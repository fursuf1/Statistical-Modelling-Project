# %% [markdown]
# # CityBikes

# %% [markdown]
# Send a request to CityBikes for the city of your choice.

# %%
import requests

# Base URL for the CityBikes API
base_url = "https://api.citybik.es"

# Endpoint to retrieve a list of network information
endpoint = "/v2/networks"

# Make a GET request to the API endpoint
response = requests.get(base_url + endpoint)

# Check if the response status code is successful (200)
if response.status_code == 200:
    # Parse the JSON response
    data = response.json()
    
    # Extract the list of network dictionaries from the response
    networks = data.get("networks", [])
    
    # Create a list of network IDs using list comprehension
    network_ids = [network.get("id") for network in networks]
    
    # Print the list of network IDs
    print("List of Network IDs:")
    for network_id in network_ids:
        print(network_id)
else:
    # Print an error message if the API request fails
    print("Failed to retrieve data. Status code:", response.status_code)
# Out:
# List of Network IDs:
# velobike-moscow
# baerum-bysykkel
# bicincitta-siena
# cyclopolis-maroussi
# cyclopolis-nafplio
# bicincitta-parco-dei-colli-di-bergamo
# cyclopolis-aigialeia
# cyclopolis-marathon
# bicincitta-mantova
# cyclopolis-neasmyrni
# cyclopolis-moschatotavros
# cyclopolis-arxaiaolympia
# cyclopolis-kiato
# bicincitta-assemini
# cyclopolis-rhodes
# cyclopolis-florina
# bicincitta-tortoli
# cyclopolis-limnos
# bicincitta-gaeta
# bicincitta-borgarello
# bicincitta-pizzighettone-formigara
# cork
# limerick
# punpunbikeshare
# galway
# bicincitta-montecatini-terme
# bikeu-bra
# santander-cycles
# we-cycle
# bicincitta-carrara
# stadtrad-hamburg
# tigullionbike
# arbike
# velobike
# velib
# ascoli-piceno
# bigi
# girocleta
# alba
# bikemi
# biella
# chivasso
# bizi
# ecobici
# bici-in-busto
# velo-antwerpen
# cuneo
# malmobybike
# bicimad
# easybike-didymoteicho
# free-bike-sharing
# easybike-glyfada
# easybike-igoumenitsa
# lecce
# easybike-ioannina
# easybike-karditsa
# manerba-in-bici
# easybike-kavala
# easybike-kinouria
# easybike-komotini
# easybike-patra
# mar-e-bici
# easybike-rethymno
# easybike-samos
# novara
# easybike-nicosia
# easybike-mani
# easybike-irakleio
# thessbike
# athens-bikes
# goodbike
# ciclosampa
# bicicorunha
# bici-ferrol-terra
# mimuovofe
# bixi-montreal
# parma
# bixi-toronto
# sobi-hamilton
# pavia-in-bici
# bici-perugia
# austin
# bike-chattanooga
# piacenza
# pinerolo
# biketown
# reggio-emilia
# boulder
# rimini
# broward
# bublr-bikes
# reddy-bike-share
# capital-bikeshare
# charlotte
# saluzzo
# cincy-red-bike
# savigliano
# citi-bike-nyc
# terni
# cogo
# denver
# divvy
# tirano-in-bici
# elpaso
# fortworth
# udine
# greenbikeslc
# omaha
# houston
# blue-bikes
# ustica
# indego
# indiana-pacers-bikeshare
# bici-co
# madison
# metro-bike-share
# nice-ride
# speziainbici
# sanantonio
# venezia
# sobi-long-beach
# to-bike
# relay-atlanta
# bikerecife
# bikesampa
# bikerio
# bikesalvador
# bikepoa
# mibici-guadalajara
# libelo
# bikesantiago
# oslo-bysykkel
# bergen-bysykkel
# trondheim-bysykkel
# le-velo-star
# v3-bordeaux
# vlille
# idecycle
# ciclopi
# muybici
# vaibike
# cagliari
# ecobici-buenos-aires
# gira
# gimme-bike
# velo
# veloh
# valenbisi
# sellero
# lundahoj
# ugento
# tusbic
# velam
# bysykkel-lillestrom
# velocite-mulhouse
# prata-camportaccio
# velov
# bicikelj
# civitavecchia
# sevici
# longanoinbici
# li-bia-velo
# velostanlib
# cristolib
# villo
# cassano-d-adda
# velo2
# vilnius-cyclocity
# toyama-cyclocity
# bianzone-in-bici
# le-velo
# bicloo
# velocite-besancon
# rietinbici
# dublinbikes
# bicipalma
# adcb-bikeshare
# castellucchio
# velobleu
# notoinbici
# enna
# pordenone
# vel-in
# carbonia
# clujbike
# integrabike
# scegli-in-bici
# rivibike
# e-motion-trento
# dukebike
# bicing
# baksi-antalya
# baksi-bisim
# e-motion-rovereto
# baksi-istanbul
# baksi-kobis
# citybikes-helsinki
# monopoli-bike
# foli
# bicimia
# telofun
# andria
# whitebikes
# slovnaft-bajk
# cykl
# bicyklezadobreskutky
# socialbicycles-wavelo
# bicinquartucciu
# encicla
# olbia-bike
# mobibikes
# savona
# c-velo
# velivert
# brindisi
# velopop
# batumvelo
# tradate
# bikebh
# bikepetrolina
# jesinbici
# nbici
# bikebrasilia
# debikegoiania
# treviso
# bicicletar
# cajubike
# bikebelem
# sondrio
# bikesantos
# vercelli
# portofino-park-and-bike
# mibicitubici
# meglio-in-bici
# desmoines
# ossola
# greenville
# bicincitta-mezzolombardo
# bicincitta-scafati
# bicincitta-livorno
# bicincitta-forli
# bicincitta-rivarolo-canavese
# bicincitta-monserrato
# bicincitta-mezzocorona
# bicincitta-san-lazzaro-di-savena
# bicincitta-san-teodoro
# bicincitta-parco-molentargius-saline
# parkinbici
# bicincitta-gallipoli
# bicincitta-castel-guelfo-the-style-outlets
# bicincitta-san-michele-alladige
# bicincitta-modena
# bicincitta-brancaleone
# bicincitta-scandiano
# bicincitta-elmas
# bicincitta-tivat
# bicincitta-acquaviva-delle-fonti
# we-love-bike
# bicincitta-acquarica-del-capo
# bicincitta-vicolungo-the-style-outlets
# bicincitta-porto-torres
# bicincitta-cisterna-di-latina
# bicincitta-casaletto-spartano
# bicincitta-selargius
# bicincitta-monza
# bicincitta-morigerati
# bicincitta-san-donato-milanese
# bicincitta-ente-parco-del-circeo
# bicincitta-cesena
# lecco
# bicincitta-alghero
# bicincitta-san-giovanni-in-persiceto
# bicincitta-ente-parco-san-rossore
# bicincitta-treviglio
# bicincitta-lavis
# bicincitta-ente-parco-di-montemarcello-magra
# bicischio
# bicincitta-imola
# nextbike-leipzig
# nextbike-wiesbaden
# visa-frankfurt
# kvb-rad-koln
# facherrad-karlsruhe
# burgenland-neusiedler-see
# nextbike-dusseldorf
# nextbike-stpolten
# nextbike-modling
# nextbike-sursee
# nextbike-luzern
# sixt-riga
# metropolradruhr-dortmund
# metropolradruhr-bochum
# metropolradruhr-bottrop
# metropolradruhr-duisburg
# metropolradruhr-essen
# metropolradruhr-gelsenkirchen
# metropolradruhr-hamm
# metropolradruhr-herne
# metropolradruhr-mulheim-adr
# metropolradruhr-oberhausen
# nextbike-wachau
# nextbike-tulln
# nextbike-thermenregion
# wrm-wroclaw
# nextbike-offenburg
# nextbike-wrneustadt
# nextbike-potsdam
# nextbike-gutersloh
# nextbike-10vorwien
# usedomrad-usedom
# nextbike-norderstedt
# swa-rad-augsburg
# nextbike-limassol
# nextbike-christchurch
# vrn-heidelberg
# vrn-mannheim
# stadtrad-innsbruck
# nextbike-nicosia
# nextbike-hollabrunn
# nextbike-wienerwald
# nextbike-zagreb
# nextbike-glasgow
# belfastbikes-belfast
# nextbike-stirling
# grad-sibenik-sibenik
# lrm-lublin-lublin
# vrn-ludwigshafen
# vrn-speyer
# nextbike-lviv
# nextbike-wurzburg
# nextbike-serfaus
# nextbike-malta
# grad-karlovac-karlovac
# grad-slavonski-brod-slavonski-brod
# santander-cycles-mk-milton-keynes
# nextbike-hergiswil
# grad-makarska-makarska
# opcina-brinje-brinje
# grad-zadar-zadar
# vrn-bensheim
# grad-ivanic-grad-ivanic-grad
# nextbike-sarajevo
# co-bikes-exeter
# nextbike-auckland-waterfront
# nextbike-berlin
# wk-bike-bremen-bremen
# vrn-worms
# nextbike-stans
# nextbike-stansstad
# nextbike-horw
# vrn-burstadt
# nextbike-gross-enzersdorf
# nextbike-klagenfurt
# vrn-kaiserslautern
# sitycleta-las-palmas-las-palmas-de-gran-canaria
# grad-velika-gorica-velika-gorica
# grad-sisak-sisak
# grad-metkovic-metkovic
# jastrebarsko-jastrebarsko
# grad-drnis-drnis
# nextbike-tuzla
# arriva-nitra
# nextbike-marburg
# bubi
# nextbike-russelsheim-am-main
# vrn-heppenheim
# nextbike-kassel
# nextbike-sarnen
# nextbike-wolfenschiessen
# nextbike-oberdorf
# nextbike-giessen
# vrn-weinheim
# nextbike-cardiff
# vrn-hockenheim
# vrn-schwetzingen
# nextbike-ennetmoos
# vrn-eppelheim
# nextbike-university-of-surrey
# santander-cycles-swansea-swansea-university
# nextbike-erfurt
# bl-bike-banja-luka
# lahr-pedelecs-lahr
# lviv-odessa
# santander-monchengladbach
# nomagobikes-celje
# bilbon-bizi
# nomagobikes-lasko
# nextbike-lippstadt
# bikekia-zilina
# nextbike-vinnytsia
# nextbike-bonn
# rowerowe-lodzkie-rl-koluszki
# rowerowe-lodzkie-rl-lask
# rowerowe-lodzkie-rl-lowicz
# rowerowe-lodzkie-rl-pabianice
# rowerowe-lodzkie-rl-sieradz
# rowerowe-lodzkie-rl-skierniewice
# rowerowe-lodzkie-rl-zdunska-wola
# rowerowe-lodzkie-rl-zgierz
# rowerowe-lodzkie-rl-kutno
# rowerowe-lodzkie-rl-lodz-rl
# frelo-freiburg
# bicincitta-trieste
# mobibike-dresden
# velobike-murmansk
# velobike-nizhniy-novgorod
# nextbike-ivano-frankivsk
# almatybike
# shymkentbike
# bay-wheels
# veloceo
# monabike
# tlp-velo
# zebullo
# velectin
# rubis-velo
# tanlib
# marseillan
# via-velo
# velyceo
# velocite-laon
# velo-baulois
# le-marcel
# tempo-velo
# semo
# cyclovis
# chantrerie-captainbike
# saclay-captainbike
# velok
# wienmobil-rad
# bikeverona
# sprottenflotte-kiel
# velomagg
# rtc-bike-share
# spokies
# alsa-nextbike-leon
# velhop
# optymo
# nextbike-prostejov
# nextbike-focsani
# grad-vukovar
# grad-zapresic
# santander-brunel
# pobiedziski-rower-gminny-pobiedziska
# piotrkowski-rower-miejski-piotrkow-trybunalski
# sap-walldorf
# opcina-pitomaca
# nomago-ljubljana
# system-roweru-gminnego-pielgrzymka
# rvk
# wupsi
# lovesharing-canary-islands-gran-canaria
# lovesharing-canary-islands-lanzarote
# lovesharing-canary-islands-fuerteventura
# vagrad
# grad-split
# grad-split-solin
# grad-split-opcina-klis
# grad-split-opcina-hrvace
# grad-split-opcina-otok-dalmatinski
# grad-split-sinj
# grad-split-podstrana
# grad-split-trogir
# nextbike-ostrava
# nextbike-ostrava-hlucin
# nextbike-ostrava-vresina
# ibizi-ibiza-city
# sprintrad
# komornicki-system-rowerowy-komorniki
# nextbike-havirov
# nextbike-berounsko
# ready4green-graben
# oleski-rower-miejski-olesno
# styr-staell-goeteborg
# nibelungen-bike-braunschweig
# nextbike-brno
# nextbike-brno-kurim
# nextbike-praha
# nextbike-praha-ricany
# nextbike-olomouc
# nextbike-kladno
# nextbike-opava
# nextbike-bielefeld
# yoy-san-luis-potosi
# yoy-san-luis-potosi-cancun
# bergisches-e-bike
# nextbike-pardubice
# nextbike-hradec-kralove
# nextbike-mladoboleslavsko-mlada-boleslav
# nextbike-mladoboleslavsko-mnichovo-hradiste
# oeynrad-bad-oeynhausen
# rsvg-bike
# citybikelinz
# velopark-drobeta
# nomago-gorica
# saturn
# nextbike-frydek-mistek
# nextbike-uherske-hradiste
# nextbike-zlin
# nextbike-krnov
# eifel
# nextbike-rychnovsko
# nextbike-pisek
# nextbike-jihlava
# nomago-zanaprej
# rower-powiatowy-sokolow-podlaski
# nextbike-bergamo
# emobi-osijek
# arval-scandicci
# nextbike-oldenburg
# nextbike-urdaibai
# mvrad-hq
# mvrad-anklam
# greifswald
# nextbike-dvur-kralove
# vvtregiorad-kufstein
# vvtregiorad-ellmau
# ski-rower-chelm
# nextbike-vrchlabi
# winsenrad
# nomago-portoroz
# vrn-landau
# velocity-aachen
# avelo-quebec
# acces-velo-saguenay
# vilvolt
# velobaie
# donkey-gh
# mbajk
# publibike-zuerich
# publibike-sierre
# publibike-region-de-nyon
# publibike-bern
# publibike-sottoceneri-ti
# publibike-fribourg
# publibike-lausanne-morges
# publibike-sion
# lovelolibreservice
# waterford
# cyclopolis-loutraki
# cyclopolis-igoumenitsa
# cyclopolis-edessa
# cyclopolis-syros
# cyclopolis-chania
# torvelo
# gijon
# auxrmlevelo
# zena-by-bike
# ambici-badalona
# ambici-cornella-de-llobregat
# ambici-santa-coloma-de-gramenet
# ambici-el-prat-de-llobregat
# ambici-castelldefels
# ambici-viladecans
# ambici-gava
# ambici-esplugues-de-llobregat
# ambici-sant-joan-despi
# ambici-molins-de-rei
# ambici-sant-just-desvern
# ambici-sant-boi-de-llobregat
# heraeus-hanau
# stari-grad-hvar
# revgmobic
# westbike-erkelenz
# westbike-geilenkirchen
# westbike-heinsberg
# westbike-hueckelhoven
# westbike-wegberg
# edeka-gruenheide-mark
# nextbike-erlangen
# nomago-gorizia
# mvg-meinrad-nextbike-mainz
# veturilo-nextbike-warsaw
# divia-velodi
# twisto-velo
# veloplus-velotao
# velitul
# citi-bike-miami
# bicincitta-costa-blu
# bicincitta-pista
# bicincitta-monteriggioni
# bicincitta-massa
# bikenmedio
# biciarousa
# bealler
# albabici
# bicialcazar
# tallinja-bike
# tugo-bike-share

# %% [markdown]
# Parse through the response to get the details you want for the bike stations in that city (latitude, longitude, number of bikes).

# %%
import requests

# Define the network ID for Citi Bike in New York City
network_id = "citi-bike-nyc"

# Base URL for the CityBikes API
base_url = "https://api.citybik.es"

# Construct the endpoint to get station information for the specified network
endpoint = f"/v2/networks/{network_id}"

# Make a GET request to the API endpoint
response = requests.get(base_url + endpoint)

# Check if the response status code is successful (200)
if response.status_code == 200:
    # Parse the JSON response
    data = response.json()
    
    # Get the list of station dictionaries from the response
    stations = data.get("network", {}).get("stations", [])
    
    # Initialize variables to keep track of total available bikes, total bikes, and total empty slots
    total_available_bikes = 0
    total_bikes = 0
    
    # Iterate through each station and extract relevant information
    for station in stations:
        station_name = station.get("name")
        latitude = station.get("latitude")
        longitude = station.get("longitude")
        available_bikes = station.get("free_bikes")
        empty_slots = station.get("empty_slots")
        total_bikes_at_station = available_bikes + empty_slots
        
        # Print station details
        print("Station:", station_name)
        print("Latitude:", latitude)
        print("Longitude:", longitude)
        print("Available Bikes:", available_bikes)
        print("Empty Slots:", empty_slots)
        print("Total Bikes at Station:", total_bikes_at_station)
        print("------------------------")
        
        # Update the total available bikes count
        total_available_bikes += available_bikes
        # Update the total bikes count
        total_bikes += total_bikes_at_station
    
    # Print the total number of available bikes in the network
    print("Total Available Bikes in Network:", total_available_bikes)
    # Print the total number of bikes (available + empty slots) in the network
    print("Total Bikes in Network:", total_bikes)
    
else:
    # Print an error message if the API request fails
    print("Failed to retrieve data. Status code:", response.status_code)
# Out:
# Station: W 100 St & Manhattan Ave
# Latitude: 40.795
# Longitude: -73.9645
# Available Bikes: 22
# Empty Slots: 16
# Total Bikes at Station: 38
# ------------------------
# Station: 7 Ave & Central Park South
# Latitude: 40.7667405590595
# Longitude: -73.9790689945221
# Available Bikes: 5
# Empty Slots: 65
# Total Bikes at Station: 70
# ------------------------
# Station: Bedford Ave & Bergen St
# Latitude: 40.676368
# Longitude: -73.952918
# Available Bikes: 1
# Empty Slots: 19
# Total Bikes at Station: 20
# ------------------------
# Station: 28 St & 41 Ave
# Latitude: 40.751047
# Longitude: -73.93797
# Available Bikes: 7
# Empty Slots: 16
# Total Bikes at Station: 23
# ------------------------
# Station: Frederick Douglass Blvd & W 112 St
# Latitude: 40.801694
# Longitude: -73.957145
# Available Bikes: 10
# Empty Slots: 25
# Total Bikes at Station: 35
# ------------------------
# Station: 3 Ave & E 112 St
# Latitude: 40.795508
# Longitude: -73.941606
# Available Bikes: 11
# Empty Slots: 10
# Total Bikes at Station: 21
# ------------------------
# Station: 8 Ave & W 31 St
# Latitude: 40.7505853470215
# Longitude: -73.9946848154068
# Available Bikes: 4
# Empty Slots: 88
# Total Bikes at Station: 92
# ------------------------
# Station: Bergen St & Vanderbilt Ave
# Latitude: 40.6794388
# Longitude: -73.9680438
# Available Bikes: 5
# Empty Slots: 22
# Total Bikes at Station: 27
# ------------------------
# Station: Monroe St & Bedford Ave
# Latitude: 40.6851443
# Longitude: -73.95380904
# Available Bikes: 7
# Empty Slots: 13
# Total Bikes at Station: 20
# ------------------------
# Station: 35 Ave & 37 St
# Latitude: 40.7557327
# Longitude: -73.9236611
# Available Bikes: 13
# Empty Slots: 16
# Total Bikes at Station: 29
# ------------------------
# Station: Bank St & Hudson St
# Latitude: 40.73652889
# Longitude: -74.00618026
# Available Bikes: 11
# Empty Slots: 10
# Total Bikes at Station: 21
# ------------------------
# Station: Greenwich St & W Houston St
# Latitude: 40.728846
# Longitude: -74.008591
# Available Bikes: 51
# Empty Slots: 25
# Total Bikes at Station: 76
# ------------------------
# Station: Madison St & Clinton St
# Latitude: 40.71269042
# Longitude: -73.98776323
# Available Bikes: 31
# Empty Slots: 7
# Total Bikes at Station: 38
# ------------------------
# Station: Stanton St & Mangin St
# Latitude: 40.71782143
# Longitude: -73.97628939
# Available Bikes: 0
# Empty Slots: 16
# Total Bikes at Station: 16
# ------------------------
# Station: Clinton Ave & Flushing Ave
# Latitude: 40.69794
# Longitude: -73.96986848
# Available Bikes: 21
# Empty Slots: 0
# Total Bikes at Station: 21
# ------------------------
# Station: Rivington St & Ridge St
# Latitude: 40.71850211
# Longitude: -73.98329859
# Available Bikes: 35
# Empty Slots: 20
# Total Bikes at Station: 55
# ------------------------
# Station: E 114 St & 1 Ave
# Latitude: 40.7945663
# Longitude: -73.9362541
# Available Bikes: 17
# Empty Slots: 6
# Total Bikes at Station: 23
# ------------------------
# Station: Columbia St & Lorraine St
# Latitude: 40.6747055
# Longitude: -74.0075572
# Available Bikes: 36
# Empty Slots: 1
# Total Bikes at Station: 37
# ------------------------
# Station: 11 Ave & W 41 St
# Latitude: 40.76030096
# Longitude: -73.99884222
# Available Bikes: 1
# Empty Slots: 43
# Total Bikes at Station: 44
# ------------------------
# Station: Riverside Dr & W 104 St
# Latitude: 40.8013434
# Longitude: -73.9711457439
# Available Bikes: 12
# Empty Slots: 40
# Total Bikes at Station: 52
# ------------------------
# Station: Dwight St & Van Dyke St
# Latitude: 40.67363551341504
# Longitude: -74.01195555925369
# Available Bikes: 19
# Empty Slots: 2
# Total Bikes at Station: 21
# ------------------------
# Station: E 97 St & Madison Ave
# Latitude: 40.787801
# Longitude: -73.953559
# Available Bikes: 37
# Empty Slots: 1
# Total Bikes at Station: 38
# ------------------------
# Station: Union St & 4 Ave
# Latitude: 40.6772744
# Longitude: -73.98282002
# Available Bikes: 22
# Empty Slots: 1
# Total Bikes at Station: 23
# ------------------------
# Station: Berkeley Pl & 6 Ave
# Latitude: 40.6765304
# Longitude: -73.97846879
# Available Bikes: 30
# Empty Slots: 6
# Total Bikes at Station: 36
# ------------------------
# Station: Waterbury St & Stagg St
# Latitude: 40.71019
# Longitude: -73.93734
# Available Bikes: 10
# Empty Slots: 11
# Total Bikes at Station: 21
# ------------------------
# Station: 3 Ave & Schermerhorn St
# Latitude: 40.68683208
# Longitude: -73.9796772
# Available Bikes: 27
# Empty Slots: 3
# Total Bikes at Station: 30
# ------------------------
# Station: Pike St & E Broadway
# Latitude: 40.71406667
# Longitude: -73.99293911
# Available Bikes: 32
# Empty Slots: 2
# Total Bikes at Station: 34
# ------------------------
# Station: Lafayette St & E 8 St
# Latitude: 40.73020660529954
# Longitude: -73.99102628231049
# Available Bikes: 21
# Empty Slots: 77
# Total Bikes at Station: 98
# ------------------------
# Station: Knickerbocker Ave & Thames St
# Latitude: 40.70539
# Longitude: -73.92976
# Available Bikes: 16
# Empty Slots: 0
# Total Bikes at Station: 16
# ------------------------
# Station: Devoe St & Morgan Ave
# Latitude: 40.713811
# Longitude: -73.93515
# Available Bikes: 3
# Empty Slots: 14
# Total Bikes at Station: 17
# ------------------------
# Station: McKibbin St & Bogart St
# Latitude: 40.706237
# Longitude: -73.933871
# Available Bikes: 27
# Empty Slots: 2
# Total Bikes at Station: 29
# ------------------------
# Station: Central Ave & Flushing Ave
# Latitude: 40.702831
# Longitude: -73.9333
# Available Bikes: 16
# Empty Slots: 4
# Total Bikes at Station: 20
# ------------------------
# Station: Central Ave & Starr Street
# Latitude: 40.700003
# Longitude: -73.92834
# Available Bikes: 13
# Empty Slots: 7
# Total Bikes at Station: 20
# ------------------------
# Station: Knickerbocker Ave & George St
# Latitude: 40.704425
# Longitude: -73.92836
# Available Bikes: 7
# Empty Slots: 14
# Total Bikes at Station: 21
# ------------------------
# Station: Irving Ave & DeKalb Ave
# Latitude: 40.7027
# Longitude: -73.92095
# Available Bikes: 24
# Empty Slots: 3
# Total Bikes at Station: 27
# ------------------------
# Station: Adelphi St & Myrtle Ave
# Latitude: 40.69308257
# Longitude: -73.97178913
# Available Bikes: 7
# Empty Slots: 18
# Total Bikes at Station: 25
# ------------------------
# Station: 1 Ave & E 68 St
# Latitude: 40.76500525
# Longitude: -73.95818491
# Available Bikes: 11
# Empty Slots: 0
# Total Bikes at Station: 11
# ------------------------
# Station: 1 Ave & E 62 St
# Latitude: 40.7612274
# Longitude: -73.96094022
# Available Bikes: 7
# Empty Slots: 31
# Total Bikes at Station: 38
# ------------------------
# Station: 5 Ave & E 78 St
# Latitude: 40.77632142182271
# Longitude: -73.96427392959595
# Available Bikes: 21
# Empty Slots: 20
# Total Bikes at Station: 41
# ------------------------
# Station: Washington Ave & Greene Ave
# Latitude: 40.68650065
# Longitude: -73.96563307
# Available Bikes: 16
# Empty Slots: 1
# Total Bikes at Station: 17
# ------------------------
# Station: Concord St & Bridge St
# Latitude: 40.69766564
# Longitude: -73.98476437
# Available Bikes: 17
# Empty Slots: 2
# Total Bikes at Station: 19
# ------------------------
# Station: Glenwood Ave
# Latitude: 40.72755146730012
# Longitude: -74.07106071710587
# Available Bikes: 5
# Empty Slots: 12
# Total Bikes at Station: 17
# ------------------------
# Station: Jay St & York St
# Latitude: 40.701403172577244
# Longitude: -73.98672670125961
# Available Bikes: 38
# Empty Slots: 0
# Total Bikes at Station: 38
# ------------------------
# Station: E 106 St & Madison Ave
# Latitude: 40.7934337
# Longitude: -73.94945003
# Available Bikes: 21
# Empty Slots: 1
# Total Bikes at Station: 22
# ------------------------
# Station: Smith St & 3 St
# Latitude: 40.6787242
# Longitude: -73.99599099
# Available Bikes: 12
# Empty Slots: 9
# Total Bikes at Station: 21
# ------------------------
# Station: Cathedral Pkwy & Broadway
# Latitude: 40.804213
# Longitude: -73.96699104
# Available Bikes: 0
# Empty Slots: 22
# Total Bikes at Station: 22
# ------------------------
# Station: 3 St & Hoyt St
# Latitude: 40.6777287
# Longitude: -73.99364123
# Available Bikes: 50
# Empty Slots: 1
# Total Bikes at Station: 51
# ------------------------
# Station: W 34 St & 11 Ave
# Latitude: 40.75594159
# Longitude: -74.0021163
# Available Bikes: 62
# Empty Slots: 13
# Total Bikes at Station: 75
# ------------------------
# Station: E 33 St & 5 Ave
# Latitude: 40.74765947
# Longitude: -73.98490707
# Available Bikes: 17
# Empty Slots: 37
# Total Bikes at Station: 54
# ------------------------
# Station: E 51 St & Lexington Ave
# Latitude: 40.75714758
# Longitude: -73.97207836
# Available Bikes: 37
# Empty Slots: 35
# Total Bikes at Station: 72
# ------------------------
# Station: 2 Ave & E 31 St
# Latitude: 40.74290902
# Longitude: -73.97706058
# Available Bikes: 4
# Empty Slots: 50
# Total Bikes at Station: 54
# ------------------------
# Station: St Johns Pl & Washington Ave
# Latitude: 40.6737236
# Longitude: -73.9631611
# Available Bikes: 0
# Empty Slots: 27
# Total Bikes at Station: 27
# ------------------------
# Station: Underhill Ave & Lincoln Pl
# Latitude: 40.6740123
# Longitude: -73.9671457
# Available Bikes: 3
# Empty Slots: 18
# Total Bikes at Station: 21
# ------------------------
# Station: Lincoln Pl & Classon Ave
# Latitude: 40.6721683
# Longitude: -73.9609
# Available Bikes: 1
# Empty Slots: 26
# Total Bikes at Station: 27
# ------------------------
# Station: Union St & Bedford Ave
# Latitude: 40.6691783
# Longitude: -73.9554162
# Available Bikes: 1
# Empty Slots: 22
# Total Bikes at Station: 23
# ------------------------
# Station: 34 Ave & 13 St
# Latitude: 40.7638753
# Longitude: -73.9364848
# Available Bikes: 12
# Empty Slots: 5
# Total Bikes at Station: 17
# ------------------------
# Station: Bedford Ave & S 9 St
# Latitude: 40.70853074
# Longitude: -73.96408963
# Available Bikes: 2
# Empty Slots: 18
# Total Bikes at Station: 20
# ------------------------
# Station: E 45 St & 3 Ave
# Latitude: 40.75255434
# Longitude: -73.97282625
# Available Bikes: 19
# Empty Slots: 19
# Total Bikes at Station: 38
# ------------------------
# Station: E 10 St & Avenue A
# Latitude: 40.72740794
# Longitude: -73.98142006
# Available Bikes: 12
# Empty Slots: 87
# Total Bikes at Station: 99
# ------------------------
# Station: 3 Ave & E 71 St
# Latitude: 40.76873687
# Longitude: -73.96119945
# Available Bikes: 10
# Empty Slots: 30
# Total Bikes at Station: 40
# ------------------------
# Station: E 81 St & York Ave
# Latitude: 40.7728384
# Longitude: -73.94989233
# Available Bikes: 4
# Empty Slots: 30
# Total Bikes at Station: 34
# ------------------------
# Station: Union Ave & N 12 St
# Latitude: 40.71924
# Longitude: -73.95242
# Available Bikes: 23
# Empty Slots: 16
# Total Bikes at Station: 39
# ------------------------
# Station: Graham Ave & Herbert St
# Latitude: 40.71929301
# Longitude: -73.94500379
# Available Bikes: 16
# Empty Slots: 6
# Total Bikes at Station: 22
# ------------------------
# Station: Hancock St & Bedford Ave
# Latitude: 40.68216564
# Longitude: -73.95399026
# Available Bikes: 4
# Empty Slots: 16
# Total Bikes at Station: 20
# ------------------------
# Station: Macon St & Nostrand Ave
# Latitude: 40.6809833854
# Longitude: -73.9500479759
# Available Bikes: 10
# Empty Slots: 12
# Total Bikes at Station: 22
# ------------------------
# Station: W 21 St & 6 Ave
# Latitude: 40.74173969
# Longitude: -73.99415556
# Available Bikes: 38
# Empty Slots: 32
# Total Bikes at Station: 70
# ------------------------
# Station: Irving Ave & Jefferson St
# Latitude: 40.70538
# Longitude: -73.92535
# Available Bikes: 11
# Empty Slots: 7
# Total Bikes at Station: 18
# ------------------------
# Station: Washington Pl & Broadway
# Latitude: 40.72903917
# Longitude: -73.99404649
# Available Bikes: 16
# Empty Slots: 4
# Total Bikes at Station: 20
# ------------------------
# Station: W 20 St & 7 Ave
# Latitude: 40.74238787
# Longitude: -73.99726235
# Available Bikes: 3
# Empty Slots: 39
# Total Bikes at Station: 42
# ------------------------
# Station: Pike St & Monroe St
# Latitude: 40.71173107
# Longitude: -73.99193043
# Available Bikes: 15
# Empty Slots: 9
# Total Bikes at Station: 24
# ------------------------
# Station: Reade St & Broadway
# Latitude: 40.71450451
# Longitude: -74.00562789
# Available Bikes: 31
# Empty Slots: 28
# Total Bikes at Station: 59
# ------------------------
# Station: Cherry St
# Latitude: 40.71219906
# Longitude: -73.97948148
# Available Bikes: 4
# Empty Slots: 28
# Total Bikes at Station: 32
# ------------------------
# Station: Warren St & Court St
# Latitude: 40.686371
# Longitude: -73.99383324
# Available Bikes: 26
# Empty Slots: 3
# Total Bikes at Station: 29
# ------------------------
# Station: E 98 St & Park Ave
# Latitude: 40.78813
# Longitude: -73.95206
# Available Bikes: 19
# Empty Slots: 0
# Total Bikes at Station: 19
# ------------------------
# Station: E 93 St & 2 Ave
# Latitude: 40.782454175279874
# Longitude: -73.9489196240902
# Available Bikes: 41
# Empty Slots: 25
# Total Bikes at Station: 66
# ------------------------
# Station: 5 Ave & E 93 St
# Latitude: 40.7857851
# Longitude: -73.957481
# Available Bikes: 11
# Empty Slots: 29
# Total Bikes at Station: 40
# ------------------------
# Station: W 92 St & Broadway
# Latitude: 40.7921
# Longitude: -73.9739
# Available Bikes: 7
# Empty Slots: 10
# Total Bikes at Station: 17
# ------------------------
# Station: Bayard St & Leonard St
# Latitude: 40.71915571696044
# Longitude: -73.94885390996933
# Available Bikes: 40
# Empty Slots: 1
# Total Bikes at Station: 41
# ------------------------
# Station: Devoe St & Lorimer St
# Latitude: 40.71335226222875
# Longitude: -73.9491033554077
# Available Bikes: 5
# Empty Slots: 13
# Total Bikes at Station: 18
# ------------------------
# Station: Lenox Ave & W 126 St
# Latitude: 40.808442
# Longitude: -73.9452087
# Available Bikes: 31
# Empty Slots: 0
# Total Bikes at Station: 31
# ------------------------
# Station: Jackson St & Leonard St
# Latitude: 40.71638031973561
# Longitude: -73.94821286201477
# Available Bikes: 10
# Empty Slots: 11
# Total Bikes at Station: 21
# ------------------------
# Station: Leonard St & Maujer St
# Latitude: 40.7103685423523
# Longitude: -73.94705951213837
# Available Bikes: 20
# Empty Slots: 1
# Total Bikes at Station: 21
# ------------------------
# Station: 31 St & Hoyt Ave N
# Latitude: 40.7711528
# Longitude: -73.9170074
# Available Bikes: 5
# Empty Slots: 30
# Total Bikes at Station: 35
# ------------------------
# Station: Astoria Park S & Shore Blvd
# Latitude: 40.7767
# Longitude: -73.927631
# Available Bikes: 23
# Empty Slots: 5
# Total Bikes at Station: 28
# ------------------------
# Station: St Nicholas Ave & Manhattan Ave
# Latitude: 40.809725
# Longitude: -73.953149
# Available Bikes: 25
# Empty Slots: 2
# Total Bikes at Station: 27
# ------------------------
# Station: Oakland Ave
# Latitude: 40.7376037
# Longitude: -74.0524783
# Available Bikes: 5
# Empty Slots: 17
# Total Bikes at Station: 22
# ------------------------
# Station: Hilltop
# Latitude: 40.7311689
# Longitude: -74.0575736
# Available Bikes: 24
# Empty Slots: 0
# Total Bikes at Station: 24
# ------------------------
# Station: Hamilton Park
# Latitude: 40.727595966
# Longitude: -74.044247311
# Available Bikes: 9
# Empty Slots: 17
# Total Bikes at Station: 26
# ------------------------
# Station: Newport PATH
# Latitude: 40.7272235
# Longitude: -74.0337589
# Available Bikes: 11
# Empty Slots: 4
# Total Bikes at Station: 15
# ------------------------
# Station: Brunswick St
# Latitude: 40.7241765
# Longitude: -74.0506564
# Available Bikes: 8
# Empty Slots: 14
# Total Bikes at Station: 22
# ------------------------
# Station: Broadway & Whipple St
# Latitude: 40.7016657
# Longitude: -73.9437303
# Available Bikes: 22
# Empty Slots: 2
# Total Bikes at Station: 24
# ------------------------
# Station: Willoughby St & Fleet St
# Latitude: 40.69196566
# Longitude: -73.9813018
# Available Bikes: 44
# Empty Slots: 16
# Total Bikes at Station: 60
# ------------------------
# Station: Washington St
# Latitude: 40.7242941
# Longitude: -74.0354826
# Available Bikes: 13
# Empty Slots: 4
# Total Bikes at Station: 17
# ------------------------
# Station: Harborside
# Latitude: 40.7192517
# Longitude: -74.034234
# Available Bikes: 10
# Empty Slots: 20
# Total Bikes at Station: 30
# ------------------------
# Station: 31 St & Newtown Ave
# Latitude: 40.7675487799971
# Longitude: -73.9209334552288
# Available Bikes: 24
# Empty Slots: 12
# Total Bikes at Station: 36
# ------------------------
# Station: Frederick Douglass Blvd & W 115 St
# Latitude: 40.8038654
# Longitude: -73.9559308
# Available Bikes: 26
# Empty Slots: 6
# Total Bikes at Station: 32
# ------------------------
# Station: Nostrand Ave & Myrtle Ave
# Latitude: 40.69527008
# Longitude: -73.95238108
# Available Bikes: 17
# Empty Slots: 1
# Total Bikes at Station: 18
# ------------------------
# Station: Myrtle Ave & Marcy Ave
# Latitude: 40.69539817
# Longitude: -73.94954908
# Available Bikes: 19
# Empty Slots: 4
# Total Bikes at Station: 23
# ------------------------
# Station: Throop Ave & Myrtle Ave
# Latitude: 40.69622937
# Longitude: -73.94371094
# Available Bikes: 10
# Empty Slots: 9
# Total Bikes at Station: 19
# ------------------------
# Station: Bank St & Washington St
# Latitude: 40.7361967
# Longitude: -74.00859207
# Available Bikes: 13
# Empty Slots: 12
# Total Bikes at Station: 25
# ------------------------
# Station: Union Ave & Wallabout St
# Latitude: 40.70029511
# Longitude: -73.95032283
# Available Bikes: 16
# Empty Slots: 11
# Total Bikes at Station: 27
# ------------------------
# Station: Lorimer St & Broadway
# Latitude: 40.70411791
# Longitude: -73.94818595
# Available Bikes: 16
# Empty Slots: 11
# Total Bikes at Station: 27
# ------------------------
# Station: Coffey St & Conover St
# Latitude: 40.677236
# Longitude: -74.015665
# Available Bikes: 24
# Empty Slots: 8
# Total Bikes at Station: 32
# ------------------------
# Station: Humboldt St & Varet St
# Latitude: 40.7031724
# Longitude: -73.940636
# Available Bikes: 33
# Empty Slots: 5
# Total Bikes at Station: 38
# ------------------------
# Station: Pioneer St & Richards St
# Latitude: 40.6777748
# Longitude: -74.0094613
# Available Bikes: 23
# Empty Slots: 0
# Total Bikes at Station: 23
# ------------------------
# Station: Van Brunt St & Wolcott St
# Latitude: 40.6773429
# Longitude: -74.01275056
# Available Bikes: 28
# Empty Slots: 6
# Total Bikes at Station: 34
# ------------------------
# Station: Pioneer St & Van Brunt St
# Latitude: 40.679043
# Longitude: -74.011169
# Available Bikes: 20
# Empty Slots: 13
# Total Bikes at Station: 33
# ------------------------
# Station: Clinton St & Joralemon St
# Latitude: 40.69239502
# Longitude: -73.99337909
# Available Bikes: 48
# Empty Slots: 0
# Total Bikes at Station: 48
# ------------------------
# Station: W 13 St & 5 Ave
# Latitude: 40.735445
# Longitude: -73.99431
# Available Bikes: 31
# Empty Slots: 7
# Total Bikes at Station: 38
# ------------------------
# Station: 47 Ave & Skillman Ave
# Latitude: 40.7437524099784
# Longitude: -73.94176483154297
# Available Bikes: 15
# Empty Slots: 3
# Total Bikes at Station: 18
# ------------------------
# Station: Vernon Blvd & 50 Ave
# Latitude: 40.74232744
# Longitude: -73.95411749
# Available Bikes: 41
# Empty Slots: 1
# Total Bikes at Station: 42
# ------------------------
# Station: Franklin St & Dupont St
# Latitude: 40.73564
# Longitude: -73.95866
# Available Bikes: 1
# Empty Slots: 25
# Total Bikes at Station: 26
# ------------------------
# Station: Milton St & Franklin St
# Latitude: 40.72906
# Longitude: -73.95779
# Available Bikes: 22
# Empty Slots: 9
# Total Bikes at Station: 31
# ------------------------
# Station: Meserole Ave & Manhattan Ave
# Latitude: 40.72708584
# Longitude: -73.95299117
# Available Bikes: 13
# Empty Slots: 11
# Total Bikes at Station: 24
# ------------------------
# Station: 31 St & Broadway
# Latitude: 40.761584
# Longitude: -73.925921
# Available Bikes: 25
# Empty Slots: 8
# Total Bikes at Station: 33
# ------------------------
# Station: Crescent St & Broadway
# Latitude: 40.7633589
# Longitude: -73.9286471
# Available Bikes: 11
# Empty Slots: 6
# Total Bikes at Station: 17
# ------------------------
# Station: 7 Ave & Park Pl
# Latitude: 40.6776147
# Longitude: -73.97324283
# Available Bikes: 9
# Empty Slots: 11
# Total Bikes at Station: 20
# ------------------------
# Station: Bergen St & Smith St
# Latitude: 40.6867443
# Longitude: -73.99063168
# Available Bikes: 45
# Empty Slots: 0
# Total Bikes at Station: 45
# ------------------------
# Station: Dean St & Hoyt St
# Latitude: 40.6864442
# Longitude: -73.98759104
# Available Bikes: 65
# Empty Slots: 7
# Total Bikes at Station: 72
# ------------------------
# Station: Bond St & Bergen St
# Latitude: 40.6849668
# Longitude: -73.98620772
# Available Bikes: 10
# Empty Slots: 13
# Total Bikes at Station: 23
# ------------------------
# Station: E 16 St & 5 Ave
# Latitude: 40.73726186
# Longitude: -73.99238967
# Available Bikes: 19
# Empty Slots: 40
# Total Bikes at Station: 59
# ------------------------
# Station: 8 Ave & W 33 St
# Latitude: 40.751551
# Longitude: -73.993934
# Available Bikes: 2
# Empty Slots: 86
# Total Bikes at Station: 88
# ------------------------
# Station: 10 St & 2 Ave
# Latitude: 40.671907
# Longitude: -73.993612
# Available Bikes: 15
# Empty Slots: 2
# Total Bikes at Station: 17
# ------------------------
# Station: Hoboken Ave at Monmouth St
# Latitude: 40.73520838045357
# Longitude: -74.04696375131607
# Available Bikes: 26
# Empty Slots: 0
# Total Bikes at Station: 26
# ------------------------
# Station: Henry St & Middagh St
# Latitude: 40.7003
# Longitude: -73.991581
# Available Bikes: 10
# Empty Slots: 22
# Total Bikes at Station: 32
# ------------------------
# Station: Allen St & Rivington St
# Latitude: 40.72019576
# Longitude: -73.98997825
# Available Bikes: 10
# Empty Slots: 26
# Total Bikes at Station: 36
# ------------------------
# Station: Market St & Cherry St
# Latitude: 40.71076228
# Longitude: -73.99400398
# Available Bikes: 32
# Empty Slots: 10
# Total Bikes at Station: 42
# ------------------------
# Station: Newton Rd & 44 St
# Latitude: 40.7595701
# Longitude: -73.9142678
# Available Bikes: 6
# Empty Slots: 12
# Total Bikes at Station: 18
# ------------------------
# Station: 28 St & 36 Ave
# Latitude: 40.757186
# Longitude: -73.932719
# Available Bikes: 4
# Empty Slots: 24
# Total Bikes at Station: 28
# ------------------------
# Station: Verona Pl & Fulton St
# Latitude: 40.6803560840434
# Longitude: -73.9476791024208
# Available Bikes: 10
# Empty Slots: 9
# Total Bikes at Station: 19
# ------------------------
# Station: 37 Ave & 35 St
# Latitude: 40.7531106
# Longitude: -73.9279917
# Available Bikes: 2
# Empty Slots: 20
# Total Bikes at Station: 22
# ------------------------
# Station: Crescent St & 35 Ave
# Latitude: 40.7596276
# Longitude: -73.9321455
# Available Bikes: 18
# Empty Slots: 5
# Total Bikes at Station: 23
# ------------------------
# Station: 21 St & 36 Ave
# Latitude: 40.7601853
# Longitude: -73.9362726
# Available Bikes: 6
# Empty Slots: 13
# Total Bikes at Station: 19
# ------------------------
# Station: 36 Ave & 10 St
# Latitude: 40.7614376
# Longitude: -73.9411265
# Available Bikes: 14
# Empty Slots: 4
# Total Bikes at Station: 18
# ------------------------
# Station: Monroe St & Tompkins Ave
# Latitude: 40.686203
# Longitude: -73.944694
# Available Bikes: 3
# Empty Slots: 16
# Total Bikes at Station: 19
# ------------------------
# Station: Franklin Ave & St Marks Ave
# Latitude: 40.6758324
# Longitude: -73.9561677
# Available Bikes: 0
# Empty Slots: 25
# Total Bikes at Station: 25
# ------------------------
# Station: Willoughby Ave & Walworth St
# Latitude: 40.69331716
# Longitude: -73.95381995
# Available Bikes: 10
# Empty Slots: 5
# Total Bikes at Station: 15
# ------------------------
# Station: Franklin Ave & Myrtle Ave
# Latitude: 40.694546087246025
# Longitude: -73.95801365375519
# Available Bikes: 19
# Empty Slots: 4
# Total Bikes at Station: 23
# ------------------------
# Station: 6 Ave & Canal St
# Latitude: 40.72243797
# Longitude: -74.00566443
# Available Bikes: 43
# Empty Slots: 27
# Total Bikes at Station: 70
# ------------------------
# Station: John St & William St
# Latitude: 40.70862144
# Longitude: -74.00722156
# Available Bikes: 32
# Empty Slots: 9
# Total Bikes at Station: 41
# ------------------------
# Station: Duffield St & Willoughby St
# Latitude: 40.69221589
# Longitude: -73.9842844
# Available Bikes: 27
# Empty Slots: 16
# Total Bikes at Station: 43
# ------------------------
# Station: Lefferts Pl & Franklin Ave
# Latitude: 40.680342423
# Longitude: -73.9557689392
# Available Bikes: 7
# Empty Slots: 14
# Total Bikes at Station: 21
# ------------------------
# Station: St James Pl & Pearl St
# Latitude: 40.71117416
# Longitude: -74.00016545
# Available Bikes: 22
# Empty Slots: 3
# Total Bikes at Station: 25
# ------------------------
# Station: Atlantic Ave & Fort Greene Pl
# Latitude: 40.68382604
# Longitude: -73.97632328
# Available Bikes: 34
# Empty Slots: 22
# Total Bikes at Station: 56
# ------------------------
# Station: Lafayette Ave & St James Pl
# Latitude: 40.68851534
# Longitude: -73.9647628
# Available Bikes: 2
# Empty Slots: 34
# Total Bikes at Station: 36
# ------------------------
# Station: Atlantic Ave & Furman St
# Latitude: 40.69165183
# Longitude: -73.9999786
# Available Bikes: 15
# Empty Slots: 15
# Total Bikes at Station: 30
# ------------------------
# Station: Columbus Ave & W 103 St
# Latitude: 40.7969347
# Longitude: -73.9643412291
# Available Bikes: 6
# Empty Slots: 33
# Total Bikes at Station: 39
# ------------------------
# Station: Butler St & Court St
# Latitude: 40.6849894
# Longitude: -73.99440329
# Available Bikes: 26
# Empty Slots: 6
# Total Bikes at Station: 32
# ------------------------
# Station: Prospect Park West & 8 St
# Latitude: 40.66514681533792
# Longitude: -73.97637605667114
# Available Bikes: 7
# Empty Slots: 16
# Total Bikes at Station: 23
# ------------------------
# Station: Flushing Ave & Vanderbilt Ave
# Latitude: 40.697950315695444
# Longitude: -73.97077560424805
# Available Bikes: 21
# Empty Slots: 1
# Total Bikes at Station: 22
# ------------------------
# Station: North Moore St & Greenwich St
# Latitude: 40.72019521437465
# Longitude: -74.0103006362915
# Available Bikes: 7
# Empty Slots: 0
# Total Bikes at Station: 7
# ------------------------
# Station: Montgomery St & Franklin Ave
# Latitude: 40.666439306870814
# Longitude: -73.9605563879013
# Available Bikes: 3
# Empty Slots: 15
# Total Bikes at Station: 18
# ------------------------
# Station: 36 Ave & 31 St
# Latitude: 40.75651272984955
# Longitude: -73.92957486212252
# Available Bikes: 9
# Empty Slots: 10
# Total Bikes at Station: 19
# ------------------------
# Station: Leonard St & Nassau Ave
# Latitude: 40.7239567849954
# Longitude: -73.94984364509583
# Available Bikes: 29
# Empty Slots: 4
# Total Bikes at Station: 33
# ------------------------
# Station: Myrtle Ave & St Edwards St
# Latitude: 40.69327018
# Longitude: -73.97703874
# Available Bikes: 50
# Empty Slots: 3
# Total Bikes at Station: 53
# ------------------------
# Station: Willoughby Ave & Hall St
# Latitude: 40.69196035
# Longitude: -73.96536851
# Available Bikes: 21
# Empty Slots: 22
# Total Bikes at Station: 43
# ------------------------
# Station: Perry St & Bleecker St
# Latitude: 40.73535398
# Longitude: -74.00483091
# Available Bikes: 36
# Empty Slots: 38
# Total Bikes at Station: 74
# ------------------------
# Station: DeKalb Ave & S Portland Ave
# Latitude: 40.68981035
# Longitude: -73.97493121
# Available Bikes: 13
# Empty Slots: 7
# Total Bikes at Station: 20
# ------------------------
# Station: E 72 St & York Ave
# Latitude: 40.76663814
# Longitude: -73.95348296
# Available Bikes: 30
# Empty Slots: 0
# Total Bikes at Station: 30
# ------------------------
# Station: W 67 St & Broadway
# Latitude: 40.77492513
# Longitude: -73.98266566
# Available Bikes: 5
# Empty Slots: 9
# Total Bikes at Station: 14
# ------------------------
# Station: Harrison St & Hudson St
# Latitude: 40.71870987
# Longitude: -74.0090009
# Available Bikes: 14
# Empty Slots: 22
# Total Bikes at Station: 36
# ------------------------
# Station: Laight St & Hudson St
# Latitude: 40.72185379
# Longitude: -74.00771779
# Available Bikes: 54
# Empty Slots: 30
# Total Bikes at Station: 84
# ------------------------
# Station: E 106 St & 1 Ave
# Latitude: 40.7892529
# Longitude: -73.93956237
# Available Bikes: 18
# Empty Slots: 5
# Total Bikes at Station: 23
# ------------------------
# Station: Richards St & Delavan St
# Latitude: 40.6794327
# Longitude: -74.00785041
# Available Bikes: 17
# Empty Slots: 1
# Total Bikes at Station: 18
# ------------------------
# Station: Commerce St & Van Brunt St
# Latitude: 40.6812117
# Longitude: -74.00860912
# Available Bikes: 13
# Empty Slots: 4
# Total Bikes at Station: 17
# ------------------------
# Station: Henry St & W 9 St
# Latitude: 40.6763744
# Longitude: -74.00324957
# Available Bikes: 15
# Empty Slots: 1
# Total Bikes at Station: 16
# ------------------------
# Station: Columbia St & W 9 St
# Latitude: 40.6769993
# Longitude: -74.00647134
# Available Bikes: 18
# Empty Slots: 2
# Total Bikes at Station: 20
# ------------------------
# Station: Court St & Nelson St
# Latitude: 40.6763947
# Longitude: -73.99869893
# Available Bikes: 23
# Empty Slots: 5
# Total Bikes at Station: 28
# ------------------------
# Station: Clinton St & 4 Place
# Latitude: 40.6783563
# Longitude: -74.00014502
# Available Bikes: 16
# Empty Slots: 7
# Total Bikes at Station: 23
# ------------------------
# Station: 7 St & 3 Ave
# Latitude: 40.67260298150126
# Longitude: -73.98983001708984
# Available Bikes: 16
# Empty Slots: 0
# Total Bikes at Station: 16
# ------------------------
# Station: Smith St & 9 St
# Latitude: 40.6746957
# Longitude: -73.99785768
# Available Bikes: 14
# Empty Slots: 5
# Total Bikes at Station: 19
# ------------------------
# Station: W 43 St & 10 Ave
# Latitude: 40.76009437
# Longitude: -73.99461843
# Available Bikes: 1
# Empty Slots: 89
# Total Bikes at Station: 90
# ------------------------
# Station: 12 Ave & W 40 St
# Latitude: 40.76087502
# Longitude: -74.00277668
# Available Bikes: 56
# Empty Slots: 18
# Total Bikes at Station: 74
# ------------------------
# Station: 11 Ave & W 27 St
# Latitude: 40.751396
# Longitude: -74.005226
# Available Bikes: 42
# Empty Slots: 2
# Total Bikes at Station: 44
# ------------------------
# Station: 21 St & 31 Dr
# Latitude: 40.7659
# Longitude: -73.930819
# Available Bikes: 14
# Empty Slots: 6
# Total Bikes at Station: 20
# ------------------------
# Station: Carroll St & Franklin Ave
# Latitude: 40.6679411
# Longitude: -73.9588
# Available Bikes: 3
# Empty Slots: 15
# Total Bikes at Station: 18
# ------------------------
# Station: Sullivan Pl & Bedford Ave
# Latitude: 40.6642406
# Longitude: -73.9574686
# Available Bikes: 6
# Empty Slots: 13
# Total Bikes at Station: 19
# ------------------------
# Station: 35 St & Broadway
# Latitude: 40.760339
# Longitude: -73.9222427
# Available Bikes: 4
# Empty Slots: 12
# Total Bikes at Station: 16
# ------------------------
# Station: W 49 St & 8 Ave
# Latitude: 40.76227205
# Longitude: -73.98788205
# Available Bikes: 11
# Empty Slots: 48
# Total Bikes at Station: 59
# ------------------------
# Station: W 22 St & 8 Ave
# Latitude: 40.74475148
# Longitude: -73.99915362
# Available Bikes: 11
# Empty Slots: 51
# Total Bikes at Station: 62
# ------------------------
# Station: E 51 St & 1 Ave
# Latitude: 40.75455731
# Longitude: -73.96592976
# Available Bikes: 2
# Empty Slots: 27
# Total Bikes at Station: 29
# ------------------------
# Station: E 25 St & 1 Ave
# Latitude: 40.7381765
# Longitude: -73.97738662
# Available Bikes: 9
# Empty Slots: 16
# Total Bikes at Station: 25
# ------------------------
# Station: W 50 St & 9 Ave
# Latitude: 40.763604677958625
# Longitude: -73.98917958140373
# Available Bikes: 0
# Empty Slots: 27
# Total Bikes at Station: 27
# ------------------------
# Station: Park Pl & Church St
# Latitude: 40.71334184275907
# Longitude: -74.00935515761375
# Available Bikes: 33
# Empty Slots: 20
# Total Bikes at Station: 53
# ------------------------
# Station: N 11 St & Kent Ave
# Latitude: 40.72248188638219
# Longitude: -73.95921930670738
# Available Bikes: 18
# Empty Slots: 6
# Total Bikes at Station: 24
# ------------------------
# Station: Jackson Square
# Latitude: 40.71113
# Longitude: -74.0789
# Available Bikes: 16
# Empty Slots: 0
# Total Bikes at Station: 16
# ------------------------
# Station: W 64 St & Thelonious Monk Circle
# Latitude: 40.77515953434235
# Longitude: -73.98918695747852
# Available Bikes: 3
# Empty Slots: 37
# Total Bikes at Station: 40
# ------------------------
# Station: Union Ave & Jackson St
# Latitude: 40.7160751
# Longitude: -73.952029
# Available Bikes: 11
# Empty Slots: 7
# Total Bikes at Station: 18
# ------------------------
# Station: Roebling St & N 4 St
# Latitude: 40.71469
# Longitude: -73.95739
# Available Bikes: 7
# Empty Slots: 17
# Total Bikes at Station: 24
# ------------------------
# Station: Metropolitan Ave & Meeker Ave
# Latitude: 40.71413311
# Longitude: -73.95234386
# Available Bikes: 9
# Empty Slots: 17
# Total Bikes at Station: 26
# ------------------------
# Station: Graham Ave & Grand St
# Latitude: 40.711863
# Longitude: -73.944024
# Available Bikes: 12
# Empty Slots: 15
# Total Bikes at Station: 27
# ------------------------
# Station: S 4 St & Rodney St
# Latitude: 40.70934
# Longitude: -73.95608
# Available Bikes: 10
# Empty Slots: 8
# Total Bikes at Station: 18
# ------------------------
# Station: Hope St & Union Ave
# Latitude: 40.71167351
# Longitude: -73.95141312
# Available Bikes: 15
# Empty Slots: 10
# Total Bikes at Station: 25
# ------------------------
# Station: Riverview Park
# Latitude: 40.7443187
# Longitude: -74.0439909
# Available Bikes: 4
# Empty Slots: 13
# Total Bikes at Station: 17
# ------------------------
# Station: 19 St & 24 Ave
# Latitude: 40.7774552
# Longitude: -73.9225403
# Available Bikes: 8
# Empty Slots: 13
# Total Bikes at Station: 21
# ------------------------
# Station: 23 Ave & 27 St
# Latitude: 40.776165
# Longitude: -73.9153175
# Available Bikes: 13
# Empty Slots: 6
# Total Bikes at Station: 19
# ------------------------
# Station: 37 St & 24 Ave
# Latitude: 40.7701477
# Longitude: -73.9120938
# Available Bikes: 7
# Empty Slots: 11
# Total Bikes at Station: 18
# ------------------------
# Station: 24 Ave & 29 St
# Latitude: 40.7729
# Longitude: -73.916142
# Available Bikes: 7
# Empty Slots: 35
# Total Bikes at Station: 42
# ------------------------
# Station: W 90 St & Amsterdam Ave
# Latitude: 40.79017948095081
# Longitude: -73.97288918495178
# Available Bikes: 6
# Empty Slots: 24
# Total Bikes at Station: 30
# ------------------------
# Station: W 89 St & Columbus Ave
# Latitude: 40.7882213
# Longitude: -73.97041561
# Available Bikes: 2
# Empty Slots: 40
# Total Bikes at Station: 42
# ------------------------
# Station: Leonard Gordon Park
# Latitude: 40.74590996631558
# Longitude: -74.0572714805603
# Available Bikes: 4
# Empty Slots: 10
# Total Bikes at Station: 14
# ------------------------
# Station: Astor Place
# Latitude: 40.71928220070702
# Longitude: -74.07126188278198
# Available Bikes: 1
# Empty Slots: 12
# Total Bikes at Station: 13
# ------------------------
# Station: Morningside Dr & Amsterdam Ave
# Latitude: 40.81028506306003
# Longitude: -73.95736455917358
# Available Bikes: 20
# Empty Slots: 13
# Total Bikes at Station: 33
# ------------------------
# Station: W 52 St & 6 Ave
# Latitude: 40.76132983124814
# Longitude: -73.97982001304626
# Available Bikes: 28
# Empty Slots: 28
# Total Bikes at Station: 56
# ------------------------
# Station: Bergen Ave
# Latitude: 40.722103786686034
# Longitude: -74.07145500183105
# Available Bikes: 8
# Empty Slots: 6
# Total Bikes at Station: 14
# ------------------------
# Station: E 60 St & York Ave
# Latitude: 40.759107
# Longitude: -73.959223
# Available Bikes: 8
# Empty Slots: 21
# Total Bikes at Station: 29
# ------------------------
# Station: E 84 St & Park Ave
# Latitude: 40.77862688
# Longitude: -73.95772073
# Available Bikes: 1
# Empty Slots: 32
# Total Bikes at Station: 33
# ------------------------
# Station: E 81 St & 3 Ave
# Latitude: 40.77573034
# Longitude: -73.9567526
# Available Bikes: 1
# Empty Slots: 44
# Total Bikes at Station: 45
# ------------------------
# Station: 5 Corners Library
# Latitude: 40.734961020009514
# Longitude: -74.0595030784607
# Available Bikes: 13
# Empty Slots: 3
# Total Bikes at Station: 16
# ------------------------
# Station: Dean St & Franklin Ave
# Latitude: 40.67759206937376
# Longitude: -73.955637216568
# Available Bikes: 1
# Empty Slots: 17
# Total Bikes at Station: 18
# ------------------------
# Station: Lincoln Park
# Latitude: 40.7246050998869
# Longitude: -74.07840594649315
# Available Bikes: 5
# Empty Slots: 13
# Total Bikes at Station: 18
# ------------------------
# Station: E 67 St & Park Ave
# Latitude: 40.76780080148132
# Longitude: -73.96592080593109
# Available Bikes: 4
# Empty Slots: 34
# Total Bikes at Station: 38
# ------------------------
# Station: W 42 St & Dyer Ave
# Latitude: 40.75898481399634
# Longitude: -73.99379968643188
# Available Bikes: 0
# Empty Slots: 32
# Total Bikes at Station: 32
# ------------------------
# Station: Lawrence St & Willoughby St
# Latitude: 40.69236178
# Longitude: -73.98631746
# Available Bikes: 26
# Empty Slots: 5
# Total Bikes at Station: 31
# ------------------------
# Station: Cadman Plaza E & Red Cross Pl
# Latitude: 40.69991755
# Longitude: -73.98971773
# Available Bikes: 28
# Empty Slots: 9
# Total Bikes at Station: 37
# ------------------------
# Station: Vesey Pl & River Terrace
# Latitude: 40.7153379
# Longitude: -74.01658354
# Available Bikes: 51
# Empty Slots: 4
# Total Bikes at Station: 55
# ------------------------
# Station: DeKalb Ave & Hudson Ave
# Latitude: 40.689888
# Longitude: -73.981013
# Available Bikes: 52
# Empty Slots: 15
# Total Bikes at Station: 67
# ------------------------
# Station: Watts St & Greenwich St
# Latitude: 40.72405549
# Longitude: -74.00965965
# Available Bikes: 11
# Empty Slots: 15
# Total Bikes at Station: 26
# ------------------------
# Station: Lenox Ave & W 117 St
# Latitude: 40.8025566
# Longitude: -73.9490782
# Available Bikes: 29
# Empty Slots: 0
# Total Bikes at Station: 29
# ------------------------
# Station: 11 St & 43 Ave
# Latitude: 40.7519071
# Longitude: -73.9479119
# Available Bikes: 20
# Empty Slots: 6
# Total Bikes at Station: 26
# ------------------------
# Station: W 120 St & Claremont Ave
# Latitude: 40.8109494
# Longitude: -73.9634
# Available Bikes: 3
# Empty Slots: 28
# Total Bikes at Station: 31
# ------------------------
# Station: E 128 St & Madison Ave
# Latitude: 40.80756
# Longitude: -73.939182
# Available Bikes: 23
# Empty Slots: 0
# Total Bikes at Station: 23
# ------------------------
# Station: E 66 St & Madison Ave
# Latitude: 40.76800889305947
# Longitude: -73.96845281124115
# Available Bikes: 4
# Empty Slots: 21
# Total Bikes at Station: 25
# ------------------------
# Station: 3 St & Prospect Park West
# Latitude: 40.668132
# Longitude: -73.97363831
# Available Bikes: 2
# Empty Slots: 24
# Total Bikes at Station: 26
# ------------------------
# Station: W 106 St & Amsterdam Ave
# Latitude: 40.8008363
# Longitude: -73.9664492472
# Available Bikes: 6
# Empty Slots: 27
# Total Bikes at Station: 33
# ------------------------
# Station: Amsterdam Ave & W 66 St
# Latitude: 40.7746671
# Longitude: -73.98470567
# Available Bikes: 2
# Empty Slots: 14
# Total Bikes at Station: 16
# ------------------------
# Station: E 102 St & 1 Ave
# Latitude: 40.7869946
# Longitude: -73.94164802
# Available Bikes: 12
# Empty Slots: 9
# Total Bikes at Station: 21
# ------------------------
# Station: Lewis Ave & Kosciuszko St
# Latitude: 40.69237074
# Longitude: -73.93705428
# Available Bikes: 9
# Empty Slots: 16
# Total Bikes at Station: 25
# ------------------------
# Station: Pulaski St & Marcus Garvey Blvd
# Latitude: 40.6933982
# Longitude: -73.939877
# Available Bikes: 8
# Empty Slots: 11
# Total Bikes at Station: 19
# ------------------------
# Station: Kosciuszko St & Nostrand Ave
# Latitude: 40.69072549
# Longitude: -73.95133465
# Available Bikes: 7
# Empty Slots: 15
# Total Bikes at Station: 22
# ------------------------
# Station: Kosciuszko St & Tompkins Ave
# Latitude: 40.69128258
# Longitude: -73.9452416
# Available Bikes: 4
# Empty Slots: 9
# Total Bikes at Station: 13
# ------------------------
# Station: Greene Ave & Throop Ave
# Latitude: 40.6894932
# Longitude: -73.942061
# Available Bikes: 8
# Empty Slots: 10
# Total Bikes at Station: 18
# ------------------------
# Station: Greene Ave & Nostrand Ave
# Latitude: 40.6883337
# Longitude: -73.950916
# Available Bikes: 9
# Empty Slots: 9
# Total Bikes at Station: 18
# ------------------------
# Station: Marcy Ave & Lafayette Ave
# Latitude: 40.6900815
# Longitude: -73.947915
# Available Bikes: 10
# Empty Slots: 10
# Total Bikes at Station: 20
# ------------------------
# Station: Putnam Ave & Throop Ave
# Latitude: 40.6851532
# Longitude: -73.94111
# Available Bikes: 9
# Empty Slots: 13
# Total Bikes at Station: 22
# ------------------------
# Station: Park Ave & Marcus Garvey Blvd
# Latitude: 40.698617
# Longitude: -73.941342
# Available Bikes: 15
# Empty Slots: 5
# Total Bikes at Station: 20
# ------------------------
# Station: Riverside Dr & W 78 St
# Latitude: 40.78414472
# Longitude: -73.98362492
# Available Bikes: 59
# Empty Slots: 0
# Total Bikes at Station: 59
# ------------------------
# Station: Driggs Ave & N 9 St
# Latitude: 40.71816969454208
# Longitude: -73.95520135760307
# Available Bikes: 40
# Empty Slots: 9
# Total Bikes at Station: 49
# ------------------------
# Station: 40 Ave & Crescent St
# Latitude: 40.753599202005596
# Longitude: -73.93795609474182
# Available Bikes: 4
# Empty Slots: 18
# Total Bikes at Station: 22
# ------------------------
# Station: E 13 St & Avenue A
# Latitude: 40.72966729392978
# Longitude: -73.98067966103554
# Available Bikes: 23
# Empty Slots: 63
# Total Bikes at Station: 86
# ------------------------
# Station: Pleasant Ave & E 120 St
# Latitude: 40.7974772
# Longitude: -73.9311847
# Available Bikes: 10
# Empty Slots: 2
# Total Bikes at Station: 12
# ------------------------
# Station: 1 Ave & E 110 St
# Latitude: 40.7923272
# Longitude: -73.9383
# Available Bikes: 1
# Empty Slots: 17
# Total Bikes at Station: 18
# ------------------------
# Station: E 115 St & Lexington Ave
# Latitude: 40.797911
# Longitude: -73.9423
# Available Bikes: 17
# Empty Slots: 5
# Total Bikes at Station: 22
# ------------------------
# Station: E 48 St & 3 Ave
# Latitude: 40.7546011026
# Longitude: -73.971878855
# Available Bikes: 30
# Empty Slots: 44
# Total Bikes at Station: 74
# ------------------------
# Station: 31 St & Northern Blvd
# Latitude: 40.75186951421875
# Longitude: -73.93349289894103
# Available Bikes: 12
# Empty Slots: 21
# Total Bikes at Station: 33
# ------------------------
# Station: E 2 St & Avenue A
# Latitude: 40.72307749068673
# Longitude: -73.98583620786667
# Available Bikes: 23
# Empty Slots: 9
# Total Bikes at Station: 32
# ------------------------
# Station: 21 St & 43 Ave
# Latitude: 40.75052534
# Longitude: -73.94594845
# Available Bikes: 16
# Empty Slots: 11
# Total Bikes at Station: 27
# ------------------------
# Station: Queens Plaza North & Crescent St
# Latitude: 40.75110165
# Longitude: -73.94073717
# Available Bikes: 5
# Empty Slots: 25
# Total Bikes at Station: 30
# ------------------------
# Station: 48 Ave & 5 St
# Latitude: 40.744363287066875
# Longitude: -73.9558732509613
# Available Bikes: 75
# Empty Slots: 3
# Total Bikes at Station: 78
# ------------------------
# Station: Jackson Ave & 46 Rd
# Latitude: 40.74524768
# Longitude: -73.94733276
# Available Bikes: 13
# Empty Slots: 12
# Total Bikes at Station: 25
# ------------------------
# Station: 44 Dr & Jackson Ave
# Latitude: 40.74718234
# Longitude: -73.9432635
# Available Bikes: 21
# Empty Slots: 6
# Total Bikes at Station: 27
# ------------------------
# Station: 46 Ave & 5 St
# Latitude: 40.74731
# Longitude: -73.95451
# Available Bikes: 16
# Empty Slots: 22
# Total Bikes at Station: 38
# ------------------------
# Station: 45 Rd & 11 St
# Latitude: 40.74708586
# Longitude: -73.94977234
# Available Bikes: 11
# Empty Slots: 7
# Total Bikes at Station: 18
# ------------------------
# Station: E 30 St & Park Ave S
# Latitude: 40.74444921
# Longitude: -73.98303529
# Available Bikes: 14
# Empty Slots: 40
# Total Bikes at Station: 54
# ------------------------
# Station: Steinway St & 23 Ave
# Latitude: 40.7713937
# Longitude: -73.9077436
# Available Bikes: 2
# Empty Slots: 15
# Total Bikes at Station: 17
# ------------------------
# Station: E 23 St & 1 Ave
# Latitude: 40.736502
# Longitude: -73.97809472
# Available Bikes: 4
# Empty Slots: 14
# Total Bikes at Station: 18
# ------------------------
# Station: Lenox Ave & W 130 St
# Latitude: 40.8107922
# Longitude: -73.9430681
# Available Bikes: 19
# Empty Slots: 4
# Total Bikes at Station: 23
# ------------------------
# Station: Court St & State St
# Latitude: 40.6902375
# Longitude: -73.99203074
# Available Bikes: 30
# Empty Slots: 1
# Total Bikes at Station: 31
# ------------------------
# Station: 5 St & 6 Ave
# Latitude: 40.6704836
# Longitude: -73.98208968
# Available Bikes: 7
# Empty Slots: 14
# Total Bikes at Station: 21
# ------------------------
# Station: 7 St & 5 Ave
# Latitude: 40.6704922
# Longitude: -73.98541675
# Available Bikes: 21
# Empty Slots: 2
# Total Bikes at Station: 23
# ------------------------
# Station: Barrow St & Hudson St
# Latitude: 40.73172428
# Longitude: -74.00674436
# Available Bikes: 25
# Empty Slots: 14
# Total Bikes at Station: 39
# ------------------------
# Station: Clinton St & Union St
# Latitude: 40.6831164
# Longitude: -73.99785267
# Available Bikes: 16
# Empty Slots: 19
# Total Bikes at Station: 35
# ------------------------
# Station: Cumberland St & Lafayette Ave
# Latitude: 40.68753406
# Longitude: -73.97265183
# Available Bikes: 13
# Empty Slots: 12
# Total Bikes at Station: 25
# ------------------------
# Station: Barclay St & Church St
# Latitude: 40.71291224
# Longitude: -74.01020234
# Available Bikes: 35
# Empty Slots: 1
# Total Bikes at Station: 36
# ------------------------
# Station: E 6 St & Avenue D
# Latitude: 40.72228087
# Longitude: -73.97668709
# Available Bikes: 3
# Empty Slots: 42
# Total Bikes at Station: 45
# ------------------------
# Station: Forsyth St & Canal St
# Latitude: 40.7158155
# Longitude: -73.99422366
# Available Bikes: 18
# Empty Slots: 3
# Total Bikes at Station: 21
# ------------------------
# Station: Pacific St & Nevins St
# Latitude: 40.6853761
# Longitude: -73.98302136
# Available Bikes: 9
# Empty Slots: 8
# Total Bikes at Station: 17
# ------------------------
# Station: Front St & Gold St
# Latitude: 40.70224
# Longitude: -73.982578
# Available Bikes: 26
# Empty Slots: 6
# Total Bikes at Station: 32
# ------------------------
# Station: Fulton St & Broadway
# Latitude: 40.711066
# Longitude: -74.009447
# Available Bikes: 39
# Empty Slots: 6
# Total Bikes at Station: 45
# ------------------------
# Station: Washington Ave & Park Ave
# Latitude: 40.69610226
# Longitude: -73.96751037
# Available Bikes: 46
# Empty Slots: 3
# Total Bikes at Station: 49
# ------------------------
# Station: Allen St & Stanton St
# Latitude: 40.722055
# Longitude: -73.989111
# Available Bikes: 41
# Empty Slots: 4
# Total Bikes at Station: 45
# ------------------------
# Station: Norfolk St & Broome St
# Latitude: 40.7172274
# Longitude: -73.98802084
# Available Bikes: 47
# Empty Slots: 5
# Total Bikes at Station: 52
# ------------------------
# Station: South St & Gouverneur Ln
# Latitude: 40.70355377
# Longitude: -74.00670227
# Available Bikes: 34
# Empty Slots: 6
# Total Bikes at Station: 40
# ------------------------
# Station: Marin Light Rail
# Latitude: 40.71458403535893
# Longitude: -74.04281705617905
# Available Bikes: 5
# Empty Slots: 19
# Total Bikes at Station: 24
# ------------------------
# Station: Communipaw & Berry Lane
# Latitude: 40.71435836870427
# Longitude: -74.06661093235016
# Available Bikes: 5
# Empty Slots: 8
# Total Bikes at Station: 13
# ------------------------
# Station: Columbus Drive
# Latitude: 40.71835519823214
# Longitude: -74.03891444206238
# Available Bikes: 2
# Empty Slots: 12
# Total Bikes at Station: 14
# ------------------------
# Station: Jersey & 3rd
# Latitude: 40.72333158646436
# Longitude: -74.04595255851744
# Available Bikes: 3
# Empty Slots: 11
# Total Bikes at Station: 14
# ------------------------
# Station: Manila & 1st
# Latitude: 40.721650724879986
# Longitude: -74.04288411140442
# Available Bikes: 9
# Empty Slots: 8
# Total Bikes at Station: 17
# ------------------------
# Station: Jersey & 6th St
# Latitude: 40.72528910781132
# Longitude: -74.04557168483734
# Available Bikes: 1
# Empty Slots: 12
# Total Bikes at Station: 13
# ------------------------
# Station: Monmouth and 6th
# Latitude: 40.72568548362901
# Longitude: -74.04879033565521
# Available Bikes: 3
# Empty Slots: 10
# Total Bikes at Station: 13
# ------------------------
# Station: Dixon Mills
# Latitude: 40.721630142638354
# Longitude: -74.04996782541275
# Available Bikes: 0
# Empty Slots: 18
# Total Bikes at Station: 18
# ------------------------
# Station: Sterling Pl & Bedford Ave
# Latitude: 40.672695
# Longitude: -73.954131
# Available Bikes: 2
# Empty Slots: 22
# Total Bikes at Station: 24
# ------------------------
# Station: W 15 St & 10 Ave
# Latitude: 40.742753828659026
# Longitude: -74.00747358798981
# Available Bikes: 37
# Empty Slots: 17
# Total Bikes at Station: 54
# ------------------------
# Station: Crescent St & 34 Ave
# Latitude: 40.76108
# Longitude: -73.930562
# Available Bikes: 11
# Empty Slots: 14
# Total Bikes at Station: 25
# ------------------------
# Station: Prospect Pl & Underhill Ave
# Latitude: 40.6769694
# Longitude: -73.96579
# Available Bikes: 2
# Empty Slots: 17
# Total Bikes at Station: 19
# ------------------------
# Station: 34 Ave & 21 St
# Latitude: 40.7628138
# Longitude: -73.9342862
# Available Bikes: 14
# Empty Slots: 9
# Total Bikes at Station: 23
# ------------------------
# Station: 2 Ave & 36 St
# Latitude: 40.65708866668485
# Longitude: -74.00870203971863
# Available Bikes: 41
# Empty Slots: 2
# Total Bikes at Station: 43
# ------------------------
# Station: 35 St & 34 Ave
# Latitude: 40.7580583
# Longitude: -73.9242751
# Available Bikes: 20
# Empty Slots: 4
# Total Bikes at Station: 24
# ------------------------
# Station: 34 Ave & 38 St
# Latitude: 40.756913
# Longitude: -73.921631
# Available Bikes: 11
# Empty Slots: 20
# Total Bikes at Station: 31
# ------------------------
# Station: Vernon Blvd & 10 St
# Latitude: 40.7671863
# Longitude: -73.9373554
# Available Bikes: 27
# Empty Slots: 12
# Total Bikes at Station: 39
# ------------------------
# Station: Washington Pl & 6 Ave
# Latitude: 40.73224119
# Longitude: -74.00026394
# Available Bikes: 10
# Empty Slots: 65
# Total Bikes at Station: 75
# ------------------------
# Station: Lafayette Ave & Classon Ave
# Latitude: 40.68900443
# Longitude: -73.96023854
# Available Bikes: 14
# Empty Slots: 11
# Total Bikes at Station: 25
# ------------------------
# Station: Douglass St & 4 Ave
# Latitude: 40.6792788
# ...
# Station: Parkside Ave & Ocean Ave
# Latitude: 40.65485
# Longitude: -73.96217
# Available Bikes: 22
# Empty Slots: 7
# Total Bikes at Station: 29
# ------------------------
# Station: Parkside Ave & Parade Pl
# Latitude: 40.6532
# Longitude: -73.96639
# Available Bikes: 22
# Empty Slots: 0
# Total Bikes at Station: 22
# ------------------------
# Station: Caton Ave & Bedford Ave
# Latitude: 40.65237
# Longitude: -73.95623
# Available Bikes: 19
# Empty Slots: 2
# Total Bikes at Station: 21
# ------------------------
# Station: 50 St & 7 Ave
# Latitude: 40.642501
# Longitude: -74.006055
# Available Bikes: 4
# Empty Slots: 16
# Total Bikes at Station: 20
# ------------------------
# Station: Linden Blvd & Nostrand Ave
# Latitude: 40.65272
# Longitude: -73.94994
# Available Bikes: 17
# Empty Slots: 4
# Total Bikes at Station: 21
# ------------------------
# Station: Rogers Ave & Lenox Rd
# Latitude: 40.65378
# Longitude: -73.95273
# Available Bikes: 17
# Empty Slots: 0
# Total Bikes at Station: 17
# ------------------------
# Station: Gansevoort St & Hudson St
# Latitude: 40.73937600789778
# Longitude: -74.00520807425661
# Available Bikes: 42
# Empty Slots: 75
# Total Bikes at Station: 117
# ------------------------
# Station: Clarkson Ave & Troy Ave
# Latitude: 40.65633
# Longitude: -73.93648
# Available Bikes: 20
# Empty Slots: 1
# Total Bikes at Station: 21
# ------------------------
# Station: Lenox Rd & E 43 St
# Latitude: 40.65496
# Longitude: -73.93765
# Available Bikes: 19
# Empty Slots: 2
# Total Bikes at Station: 21
# ------------------------
# Station: Clarkson Ave & E 37 St
# Latitude: 40.65577
# Longitude: -73.9432
# Available Bikes: 18
# Empty Slots: 2
# Total Bikes at Station: 20
# ------------------------
# Station: Troy Ave & Linden Blvd
# Latitude: 40.6533
# Longitude: -73.93644
# Available Bikes: 19
# Empty Slots: 3
# Total Bikes at Station: 22
# ------------------------
# Station: E 21 St & Church Ave
# Latitude: 40.65007
# Longitude: -73.96001
# Available Bikes: 25
# Empty Slots: 0
# Total Bikes at Station: 25
# ------------------------
# Station: Rugby Rd & Albemarle Rd
# Latitude: 40.64672
# Longitude: -73.96637
# Available Bikes: 17
# Empty Slots: 1
# Total Bikes at Station: 18
# ------------------------
# Station: Rugby Rd & Beverley Rd
# Latitude: 40.64435
# Longitude: -73.96591
# Available Bikes: 21
# Empty Slots: 1
# Total Bikes at Station: 22
# ------------------------
# Station: E 17 St & Beverley Rd
# Latitude: 40.64466
# Longitude: -73.96322
# Available Bikes: 19
# Empty Slots: 2
# Total Bikes at Station: 21
# ------------------------
# Station: 2 Ave & E 99 St
# Latitude: 40.7862586
# Longitude: -73.94552579
# Available Bikes: 21
# Empty Slots: 10
# Total Bikes at Station: 31
# ------------------------
# Station: E 18 St & Church Ave
# Latitude: 40.64958
# Longitude: -73.96316
# Available Bikes: 27
# Empty Slots: 2
# Total Bikes at Station: 29
# ------------------------
# Station: Albemarle Rd & E 21 St
# Latitude: 40.64741
# Longitude: -73.95933
# Available Bikes: 19
# Empty Slots: 0
# Total Bikes at Station: 19
# ------------------------
# Station: E 34 St & Linden Blvd
# Latitude: 40.65302
# Longitude: -73.94599
# Available Bikes: 19
# Empty Slots: 5
# Total Bikes at Station: 24
# ------------------------
# Station: E 91 St & Park Ave
# Latitude: 40.7835016
# Longitude: -73.955327
# Available Bikes: 5
# Empty Slots: 24
# Total Bikes at Station: 29
# ------------------------
# Station: Rogers Ave & Snyder Ave
# Latitude: 40.64871
# Longitude: -73.95218
# Available Bikes: 15
# Empty Slots: 4
# Total Bikes at Station: 19
# ------------------------
# Station: Church Ave & Nostrand Ave
# Latitude: 40.65074
# Longitude: -73.94986
# Available Bikes: 25
# Empty Slots: 0
# Total Bikes at Station: 25
# ------------------------
# Station: Church Ave & E 42 St
# Latitude: 40.65127
# Longitude: -73.93818
# Available Bikes: 22
# Empty Slots: 2
# Total Bikes at Station: 24
# ------------------------
# Station: Tilden Ave & Nostrand Ave
# Latitude: 40.64683
# Longitude: -73.94933
# Available Bikes: 12
# Empty Slots: 9
# Total Bikes at Station: 21
# ------------------------
# Station: Brooklyn Ave & Tilden Ave
# Latitude: 40.64725
# Longitude: -73.94352
# Available Bikes: 7
# Empty Slots: 15
# Total Bikes at Station: 22
# ------------------------
# Station: Brooklyn Ave & Snyder Ave
# Latitude: 40.64915
# Longitude: -73.94368
# Available Bikes: 20
# Empty Slots: 2
# Total Bikes at Station: 22
# ------------------------
# Station: Matthews Ct & Coney Island Ave
# Latitude: 40.64235
# Longitude: -73.96951
# Available Bikes: 18
# Empty Slots: 1
# Total Bikes at Station: 19
# ------------------------
# Station: Tilden Ave & Lott St
# Latitude: 40.64661
# Longitude: -73.95401
# Available Bikes: 17
# Empty Slots: 0
# Total Bikes at Station: 17
# ------------------------
# Station: W 18 St & 9 Ave
# Latitude: 40.7435337324616
# Longitude: -74.00367558002472
# Available Bikes: 18
# Empty Slots: 14
# Total Bikes at Station: 32
# ------------------------
# Station: Beverley Rd & Flatbush Ave
# Latitude: 40.64499
# Longitude: -73.95818
# Available Bikes: 26
# Empty Slots: 3
# Total Bikes at Station: 29
# ------------------------
# Station: W 52 St & 11 Ave
# Latitude: 40.76727216
# Longitude: -73.99392888
# Available Bikes: 34
# Empty Slots: 19
# Total Bikes at Station: 53
# ------------------------
# Station: New York Ave & Montgomery St
# Latitude: 40.66509
# Longitude: -73.94824
# Available Bikes: 7
# Empty Slots: 11
# Total Bikes at Station: 18
# ------------------------
# Station: Ocean Ave & Tennis Ct
# Latitude: 40.64873
# Longitude: -73.96084
# Available Bikes: 21
# Empty Slots: 1
# Total Bikes at Station: 22
# ------------------------
# Station: 23 Ave & 31 St
# Latitude: 40.77423301703027
# Longitude: -73.91274864321404
# Available Bikes: 12
# Empty Slots: 13
# Total Bikes at Station: 25
# ------------------------
# Station: Lott St & Erasmus St
# Latitude: 40.64949
# Longitude: -73.95408
# Available Bikes: 18
# Empty Slots: 0
# Total Bikes at Station: 18
# ------------------------
# Station: New York Ave & Snyder Ave
# Latitude: 40.64868
# Longitude: -73.94635
# Available Bikes: 22
# Empty Slots: 0
# Total Bikes at Station: 22
# ------------------------
# Station: Cortelyou Rd & Stratford Rd
# Latitude: 40.63966
# Longitude: -73.96807
# Available Bikes: 18
# Empty Slots: 0
# Total Bikes at Station: 18
# ------------------------
# Station: E 16 St & Cortelyou Rd
# Latitude: 40.64173
# Longitude: -73.96364
# Available Bikes: 21
# Empty Slots: 0
# Total Bikes at Station: 21
# ------------------------
# Station: Cortelyou Rd & Argyle Rd
# Latitude: 40.64034
# Longitude: -73.96603
# Available Bikes: 22
# Empty Slots: 1
# Total Bikes at Station: 23
# ------------------------
# Station: Ditmars Blvd & 73 St
# Latitude: 40.76817
# Longitude: -73.896293
# Available Bikes: 10
# Empty Slots: 9
# Total Bikes at Station: 19
# ------------------------
# Station: Ditmars Blvd & 76 St
# Latitude: 40.768442
# Longitude: -73.893531
# Available Bikes: 5
# Empty Slots: 14
# Total Bikes at Station: 19
# ------------------------
# Station: Cortelyou Rd & E 19 St
# Latitude: 40.64269
# Longitude: -73.96099
# Available Bikes: 20
# Empty Slots: 2
# Total Bikes at Station: 22
# ------------------------
# Station: Bedford Ave & Beverley Rd
# Latitude: 40.64491
# Longitude: -73.95487
# Available Bikes: 22
# Empty Slots: 1
# Total Bikes at Station: 23
# ------------------------
# Station: Driggs Ave & N Henry St
# Latitude: 40.72325
# Longitude: -73.94308
# Available Bikes: 16
# Empty Slots: 36
# Total Bikes at Station: 52
# ------------------------
# Station: Cortelyou Rd & E 34 St
# Latitude: 40.64454
# Longitude: -73.94486
# Available Bikes: 16
# Empty Slots: 1
# Total Bikes at Station: 17
# ------------------------
# Station: Brooklyn Ave & Beverley Rd
# Latitude: 40.64575
# Longitude: -73.94331
# Available Bikes: 18
# Empty Slots: 2
# Total Bikes at Station: 20
# ------------------------
# Station: Carlton Ave & Dean St
# Latitude: 40.6809741
# Longitude: -73.9710097
# Available Bikes: 23
# Empty Slots: 5
# Total Bikes at Station: 28
# ------------------------
# Station: 48 St & 37 Ave
# Latitude: 40.751555
# Longitude: -73.915026
# Available Bikes: 11
# Empty Slots: 16
# Total Bikes at Station: 27
# ------------------------
# Station: W 74 St & Columbus Ave
# Latitude: 40.7785669
# Longitude: -73.97754961
# Available Bikes: 4
# Empty Slots: 17
# Total Bikes at Station: 21
# ------------------------
# Station: Ocean Ave & Crooke Ave
# Latitude: 40.65326
# Longitude: -73.96172
# Available Bikes: 21
# Empty Slots: 5
# Total Bikes at Station: 26
# ------------------------
# Station: Bedford Ave & Albemarle Rd
# Latitude: 40.64796
# Longitude: -73.9556
# Available Bikes: 18
# Empty Slots: 0
# Total Bikes at Station: 18
# ------------------------
# Station: New York Ave & Lenox Rd
# Latitude: 40.65458
# Longitude: -73.94716
# Available Bikes: 21
# Empty Slots: 2
# Total Bikes at Station: 23
# ------------------------
# Station: Cortelyou Rd & Albany Ave
# Latitude: 40.64483
# Longitude: -73.93853
# Available Bikes: 19
# Empty Slots: 2
# Total Bikes at Station: 21
# ------------------------
# Station: E 48 St & Tilden Ave
# Latitude: 40.64795
# Longitude: -73.93182
# Available Bikes: 11
# Empty Slots: 15
# Total Bikes at Station: 26
# ------------------------
# Station: Beverley Rd & Nostrand Ave
# Latitude: 40.64507
# Longitude: -73.9488
# Available Bikes: 22
# Empty Slots: 0
# Total Bikes at Station: 22
# ------------------------
# Station: Turner Pl & Coney Island Ave
# Latitude: 40.64521
# Longitude: -73.97073
# Available Bikes: 18
# Empty Slots: 0
# Total Bikes at Station: 18
# ------------------------
# Station: Beverley Rd & E 49 St
# Latitude: 40.64621
# Longitude: -73.93067
# Available Bikes: 22
# Empty Slots: 0
# Total Bikes at Station: 22
# ------------------------
# Station: Schenectady Ave & Cortelyou Rd
# Latitude: 40.64535
# Longitude: -73.93268
# Available Bikes: 16
# Empty Slots: 6
# Total Bikes at Station: 22
# ------------------------
# Station: W 35 St & 9 Ave
# Latitude: 40.75414519263519
# Longitude: -73.9960889518261
# Available Bikes: 26
# Empty Slots: 2
# Total Bikes at Station: 28
# ------------------------
# Station: 21 Ave & 80 St
# Latitude: 40.770888
# Longitude: -73.889914
# Available Bikes: 10
# Empty Slots: 9
# Total Bikes at Station: 19
# ------------------------
# Station: Ditmars Blvd & 19 St
# Latitude: 40.78145
# Longitude: -73.9183302
# Available Bikes: 16
# Empty Slots: 11
# Total Bikes at Station: 27
# ------------------------
# Station: 71 St & 37 Ave
# Latitude: 40.7488
# Longitude: -73.89451
# Available Bikes: 0
# Empty Slots: 23
# Total Bikes at Station: 23
# ------------------------
# Station: 34 Ave & 71 St
# Latitude: 40.75257
# Longitude: -73.89538
# Available Bikes: 6
# Empty Slots: 15
# Total Bikes at Station: 21
# ------------------------
# Station: 72 St & Northern Blvd
# Latitude: 40.75473
# Longitude: -73.89458
# Available Bikes: 4
# Empty Slots: 14
# Total Bikes at Station: 18
# ------------------------
# Station: Ashland Pl & Dekalb Ave
# Latitude: 40.690065
# Longitude: -73.978776
# Available Bikes: 43
# Empty Slots: 2
# Total Bikes at Station: 45
# ------------------------
# Station: 3 Ave & E 109 St
# Latitude: 40.79338
# Longitude: -73.94329
# Available Bikes: 19
# Empty Slots: 4
# Total Bikes at Station: 23
# ------------------------
# Station: 14 St Ferry - 14 St & Shipyard Ln
# Latitude: 40.752960630464955
# Longitude: -74.02435272932053
# Available Bikes: 12
# Empty Slots: 19
# Total Bikes at Station: 31
# ------------------------
# Station: 34 Ave & 74 St
# Latitude: 40.75297
# Longitude: -73.89236
# Available Bikes: 9
# Empty Slots: 13
# Total Bikes at Station: 22
# ------------------------
# Station: 32 Ave & 75 St
# Latitude: 40.75704
# Longitude: -73.8924
# Available Bikes: 8
# Empty Slots: 11
# Total Bikes at Station: 19
# ------------------------
# Station: 71 St & 32 Ave
# Latitude: 40.75675
# Longitude: -73.89595
# Available Bikes: 8
# Empty Slots: 10
# Total Bikes at Station: 18
# ------------------------
# Station: Winthrop St & Schenectady Ave
# Latitude: 40.6582
# Longitude: -73.9338
# Available Bikes: 12
# Empty Slots: 9
# Total Bikes at Station: 21
# ------------------------
# Station: Winthrop St & Albany Ave
# Latitude: 40.6577
# Longitude: -73.9398
# Available Bikes: 16
# Empty Slots: 5
# Total Bikes at Station: 21
# ------------------------
# Station: 81 St & 35 Ave
# Latitude: 40.75179
# Longitude: -73.88568
# Available Bikes: 0
# Empty Slots: 21
# Total Bikes at Station: 21
# ------------------------
# Station: 74 St & 37 Ave
# Latitude: 40.74908
# Longitude: -73.89172
# Available Bikes: 11
# Empty Slots: 17
# Total Bikes at Station: 28
# ------------------------
# Station: 77 St & 31 Ave
# Latitude: 40.75886
# Longitude: -73.89081
# Available Bikes: 18
# Empty Slots: 1
# Total Bikes at Station: 19
# ------------------------
# Station: 77 St & 24 Ave
# Latitude: 40.76428
# Longitude: -73.89156
# Available Bikes: 6
# Empty Slots: 13
# Total Bikes at Station: 19
# ------------------------
# Station: 73 St & 25 Ave
# Latitude: 40.76205
# Longitude: -73.895
# Available Bikes: 4
# Empty Slots: 13
# Total Bikes at Station: 17
# ------------------------
# Station: 81 St & 24 Ave
# Latitude: 40.76466
# Longitude: -73.88803
# Available Bikes: 9
# Empty Slots: 9
# Total Bikes at Station: 18
# ------------------------
# Station: 61 St & 60 Ln
# Latitude: 40.70055
# Longitude: -73.8943
# Available Bikes: 6
# Empty Slots: 10
# Total Bikes at Station: 16
# ------------------------
# Station: 81 St & 34 Ave
# Latitude: 40.75374
# Longitude: -73.88604
# Available Bikes: 1
# Empty Slots: 24
# Total Bikes at Station: 25
# ------------------------
# Station: 32 Ave & 81 St
# Latitude: 40.75763
# Longitude: -73.88682
# Available Bikes: 4
# Empty Slots: 14
# Total Bikes at Station: 18
# ------------------------
# Station: 82 St & 30 Ave
# Latitude: 40.76109
# Longitude: -73.88632
# Available Bikes: 7
# Empty Slots: 10
# Total Bikes at Station: 17
# ------------------------
# Station: 86 St & 37 Ave
# Latitude: 40.75
# Longitude: -73.88062
# Available Bikes: 16
# Empty Slots: 6
# Total Bikes at Station: 22
# ------------------------
# Station: 84 St & Roosevelt Ave
# Latitude: 40.74797
# Longitude: -73.88204
# Available Bikes: 22
# Empty Slots: 7
# Total Bikes at Station: 29
# ------------------------
# Station: 92 St & 35 Ave
# Latitude: 40.7529
# Longitude: -73.87536
# Available Bikes: 22
# Empty Slots: 2
# Total Bikes at Station: 24
# ------------------------
# Station: Suydam St & Knickerbocker Ave
# Latitude: 40.702013
# Longitude: -73.923769
# Available Bikes: 24
# Empty Slots: 3
# Total Bikes at Station: 27
# ------------------------
# Station: W 84 St & Amsterdam Ave
# Latitude: 40.78621
# Longitude: -73.9756
# Available Bikes: 13
# Empty Slots: 38
# Total Bikes at Station: 51
# ------------------------
# Station: 86 St & 35 Ave
# Latitude: 40.7523
# Longitude: -73.88093
# Available Bikes: 7
# Empty Slots: 13
# Total Bikes at Station: 20
# ------------------------
# Station: 32 Ave & 84 St
# Latitude: 40.75793
# Longitude: -73.88401
# Available Bikes: 6
# Empty Slots: 12
# Total Bikes at Station: 18
# ------------------------
# Station: Sterling Pl & Franklin Ave
# Latitude: 40.67324785
# Longitude: -73.95689517
# Available Bikes: 1
# Empty Slots: 17
# Total Bikes at Station: 18
# ------------------------
# Station: Amsterdam Ave & W 119 St
# Latitude: 40.80863218
# Longitude: -73.9595861
# Available Bikes: 19
# Empty Slots: 8
# Total Bikes at Station: 27
# ------------------------
# Station: Freeman St & Reverend James A Polite Ave
# Latitude: 40.830529
# Longitude: -73.894717
# Available Bikes: 2
# Empty Slots: 16
# Total Bikes at Station: 18
# ------------------------
# Station: Freeman St & Southern Blvd
# Latitude: 40.830051
# Longitude: -73.892103
# Available Bikes: 0
# Empty Slots: 21
# Total Bikes at Station: 21
# ------------------------
# Station: Walton Ave & E 153 St
# Latitude: 40.822351
# Longitude: -73.926907
# Available Bikes: 8
# Empty Slots: 7
# Total Bikes at Station: 15
# ------------------------
# Station: 79 St & 37 Ave
# Latitude: 40.74937
# Longitude: -73.88714
# Available Bikes: 1
# Empty Slots: 20
# Total Bikes at Station: 21
# ------------------------
# Station: Union Ave & E 169 St
# Latitude: 40.82995
# Longitude: -73.898802
# Available Bikes: 1
# Empty Slots: 17
# Total Bikes at Station: 18
# ------------------------
# Station: 87 St & 30 Ave
# Latitude: 40.76156
# Longitude: -73.88167
# Available Bikes: 5
# Empty Slots: 16
# Total Bikes at Station: 21
# ------------------------
# Station: 85 St & Northern Blvd
# Latitude: 40.75601
# Longitude: -73.88266
# Available Bikes: 4
# Empty Slots: 18
# Total Bikes at Station: 22
# ------------------------
# Station: 25 Ave & 85 St
# Latitude: 40.76328
# Longitude: -73.88404
# Available Bikes: 3
# Empty Slots: 16
# Total Bikes at Station: 19
# ------------------------
# Station: Walton Ave & E 151 St
# Latitude: 40.82090903827738
# Longitude: -73.92753845245076
# Available Bikes: 16
# Empty Slots: 12
# Total Bikes at Station: 28
# ------------------------
# Total Available Bikes in Network: 29193
# Total Bikes in Network: 56813

# %% [markdown]
# Put your parsed results into a DataFrame.

# %%
import requests
import pandas as pd

# Define the network ID for Citi Bike in New York City
network_id = "citi-bike-nyc"

# Base URL for the CityBikes API
base_url = "https://api.citybik.es"

# Construct the endpoint to get station information for the specified network
endpoint = f"/v2/networks/{network_id}"

# Make a GET request to the API endpoint
response = requests.get(base_url + endpoint)

# Check if the response status code is successful (200)
if response.status_code == 200:
    # Parse the JSON response
    data = response.json()
    
    # Get the list of station dictionaries from the response
    stations = data.get("network", {}).get("stations", [])
    
    # Create an empty list to store station information
    station_info = []
    
    # Iterate through each station and extract relevant information
    for station in stations:
        station_name = station.get("name")
        latitude = station.get("latitude")
        longitude = station.get("longitude")
        available_bikes = station.get("free_bikes")
        empty_slots = station.get("empty_slots")
        total_bikes_at_station = available_bikes + empty_slots
        
        # Append station information to the list
        station_info.append({
            "Station Name": station_name,
            "Latitude": latitude,
            "Longitude": longitude,
            "Available Bikes": available_bikes,
            "Empty Slots": empty_slots,
            "Total Bikes at Station": total_bikes_at_station
        })
    
    # Create a pandas DataFrame from the list of station information
    df = pd.DataFrame(station_info)
    
    # Print the DataFrame
    print(df)
    
else:
    # Print an error message if the API request fails
    print("Failed to retrieve data. Status code:", response.status_code)
# Out:
#                             Station Name   Latitude  Longitude  \
# 0               W 100 St & Manhattan Ave  40.795000 -73.964500
# 1             7 Ave & Central Park South  40.766741 -73.979069
# 2                Bedford Ave & Bergen St  40.676368 -73.952918
# 3                         28 St & 41 Ave  40.751047 -73.937970
# 4     Frederick Douglass Blvd & W 112 St  40.801694 -73.957145
# ...                                  ...        ...        ...
# 1949                Union Ave & E 169 St  40.829950 -73.898802
# 1950                      87 St & 30 Ave  40.761560 -73.881670
# 1951               85 St & Northern Blvd  40.756010 -73.882660
# 1952                      25 Ave & 85 St  40.763280 -73.884040
# 1953               Walton Ave & E 151 St  40.820909 -73.927538
#
#       Available Bikes  Empty Slots  Total Bikes at Station
# 0                  22           16                      38
# 1                   5           65                      70
# 2                   1           19                      20
# 3                   7           16                      23
# 4                  10           25                      35
# ...               ...          ...                     ...
# 1949                1           17                      18
# 1950                5           16                      21
# 1951                4           18                      22
# 1952                3           16                      19
# 1953               16           12                      28
#
# [1954 rows x 6 columns]
